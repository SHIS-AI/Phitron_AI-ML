# %%
from abc import ABC,abstractmethod
## create aabstractmethod
class Telephone(ABC): 
    @abstractmethod
    def make_call(self): 
        print("macking a call")

# %%
class Sphone(Telephone):
    pass
    # def make_call(self): 
    #     print("call now.")

# %%
sphone = Sphone()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sphone = Sphone()
#
# TypeError: Can't instantiate abstract class Sphone without an implementation for abstract method 'make_call'

# %%
sphone.make_call()
# Out:
# call now.

# %%
|
